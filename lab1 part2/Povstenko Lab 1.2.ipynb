82</td><td>4</td></tr><tr><td>83</td><td>4</td></tr><tr><td>84</td><td>3</td></tr><tr><td>85</td><td>3</td></tr><tr><td>86</td><td>3</td></tr><tr><td>87</td><td>4</td></tr><tr><td>88</td><td>6</td></tr><tr><td>89</td><td>3</td></tr><tr><td>90</td><td>3</td></tr><tr><td>91</td><td>3</td></tr><tr><td>92</td><td>4</td></tr><tr><td>93</td><td>1</td></tr><tr><td>94</td><td>3</td></tr><tr><td>95</td><td>4</td></tr><tr><td>96</td><td>3</td></tr><tr><td>97</td><td>1</td></tr><tr><td>98</td><td>3</td></tr><tr><td>99</td><td>3</td></tr><tr><td>100</td><td>3</td></tr><tr><td>101</td><td>4</td></tr><tr><td>102</td><td>4</td></tr><tr><td>103</td><td>3</td></tr><tr><td>104</td><td>4</td></tr><tr><td>105</td><td>3</td></tr><tr><td>106</td><td>4</td></tr><tr><td>107</td><td>3</td></tr><tr><td>108</td><td>4</td></tr><tr><td>109</td><td>4</td></tr><tr><td>110</td><td>3</td></tr><tr><td>111</td><td>4</td></tr><tr><td>112</td><td>2</td></tr><tr><td>113</td><td>3</td></tr><tr><td>114</td><td>3</td></tr><tr><td>115</td><td>3</td></tr><tr><td>116</td><td>3</td></tr><tr><td>117</td><td>3</td></tr><tr><td>118</td><td>6</td></tr><tr><td>119</td><td>4</td></tr><tr><td>120</td><td>3</td></tr><tr><td>121</td><td>3</td></tr><tr><td>122</td><td>3</td></tr><tr><td>123</td><td>3</td></tr><tr><td>124</td><td>6</td></tr><tr><td>125</td><td>3</td></tr><tr><td>126</td><td>4</td></tr><tr><td>127</td><td>3</td></tr><tr><td>128</td><td>4</td></tr><tr><td>129</td><td>2</td></tr><tr><td>130</td><td>4</td></tr><tr><td>131</t ...

-- %% [markdown]
-- ## 2. Яка сума найбільшого замовлення?

-- %%
SELECT TOP 1 ORDERNUMBER, SUM(QUOTEDPRICE*QUANTITYORDERED) AS ORDERSUM
FROM ORDER_DETAILS
GROUP BY ORDERNUMBER
ORDER BY ORDERSUM DESC
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.012
-- <table><tr><th>ORDERNUMBER</th><th>ORDERSUM</th></tr><tr><td>165</td><td>21674,630111694336</td></tr></table>

-- %% [markdown]
-- ## 3. Клієнтів з якого міста в компанії найбільше?

-- %%
SELECT TOP 1 CUSTCITY FROM ORDERS AS O
JOIN CUSTOMERS AS C
ON O.CUSTOMERID = C.CUSTOMERID
GROUP BY CUSTCITY
ORDER BY COUNT(C.CUSTOMERID) DESC
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.011
-- <table><tr><th>CUSTCITY</th></tr><tr><td>Redmond</td></tr></table>

-- %% [markdown]
-- ## 4. Який офіс (з якого міста) дає компанії найбільші прибутки?

-- %%
SELECT TOP 1 VENDCITY, SUM(QUOTEDPRICE - WHOLESALEPRICE) AS PROFIT
FROM PRODUCTS AS P
INNER JOIN PRODUCT_VENDORS AS PV
ON P.PRODUCTNUMBER = PV.PRODUCTNUMBER
INNER JOIN VENDORS AS V
ON PV.VENDORID = V.VENDORID
INNER JOIN ORDER_DETAILS AS OD
ON P.PRODUCTNUMBER = OD.PRODUCTNUMBER
GROUP BY VENDCITY
ORDER BY PROFIT DESC
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.025
-- <table><tr><th>VENDCITY</th><th>PROFIT</th></tr><tr><td>El Paso</td><td>391313,6614435651</td></tr></table>

-- %% [markdown]
-- ## 5. Який продукт з асортименту товарів купують найбільше?

-- %%
SELECT TOP 1 P.PRODUCTNAME, SUM(O.QUANTITYORDERED) AS SUM_QUANTITYORDERED
FROM ORDER_DETAILS AS O
INNER JOIN PRODUCTS AS P
ON O.PRODUCTNUMBER = P.PRODUCTNUMBER
GROUP BY P.PRODUCTNAME
ORDER BY SUM_QUANTITYORDERED DESC
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.014
-- <table><tr><th>PRODUCTNAME</th><th>SUM_QUANTITYORDERED</th></tr><tr><td>Trek 9000 Mountain Bike                           </td><td>2198</td></tr></table>

-- %% [markdown]
-- ## 6. Виведіть перелік замовлень, які доставлялись клієнтам довше 5 днів.

-- %%
SELECT * FROM ORDERS
WHERE DATEDIFF(DAY, ORDERDATE, SHIPDATE) > 5
-- Out:
-- (0 rows affected)
-- Total execution time: 00:00:00.005
-- <table><tr><th>ORDERNUMBER</th><th>ORDERDATE</th><th>SHIPDATE</th><th>CUSTOMERID</th><th>EMPLOYEEID</th></tr></table>

-- %% [markdown]
-- ## 7. Визначте товари, яких немає в наявності. Які з цих товарів можуть бути доставлені на склад за 4 дні?

-- %%
SELECT * FROM PRODUCTS AS P
INNER JOIN PRODUCT_VENDORS AS PV
ON P.PRODUCTNUMBER = PV.PRODUCTNUMBER
WHERE DAYSTODELIVERY <= 4 AND QUANTITYONHAND = 0
-- Out:
-- (0 rows affected)
-- Total execution time: 00:00:00.006
-- <table><tr><th>PRODUCTNUMBER</th><th>PRODUCTNAME</th><th>PRODUCTDESCRIPTION</th><th>RETAILPRICE</th><th>QUANTITYONHAND</th><th>CATEGORYID</th><th>PRODUCTNUMBER</th><th>VENDORID</th><th>WHOLESALEPRICE</th><th>DAYSTODELIVERY</th></tr></table>

-- %% [markdown]
-- ## 8. Визначте товар, від продажу одиниці якого чистий прибуток фірми є найбільшим.

-- %%
SELECT TOP 1 PRODUCTNAME, MAX(RETAILPRICE - WHOLESALEPRICE) AS MAX_PROFIT
FROM PRODUCTS AS P
INNER JOIN PRODUCT_VENDORS AS PV
ON P.PRODUCTNUMBER = PV.PRODUCTNUMBER
GROUP BY PRODUCTNAME
ORDER BY MAX_PROFIT DESC
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.010
-- <table><tr><th>PRODUCTNAME</th><th>MAX_PROFIT</th></tr><tr><td>GT RTS-2 Mountain Bike                            </td><td>573,3800000000001</td></tr></table>

-- %% [markdown]
-- ## 9. Знайдіть всіх клієнтів, прізвище яких починається з літери «D» та які живуть в Портленді.

-- %%
SELECT * FROM CUSTOMERS
WHERE CUSTLASTNAME LIKE 'D%' AND CUSTCITY = 'Portland'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.007
-- <table><tr><th>CUSTOMERID</th><th>CUSTFIRSTNAME</th><th>CUSTLASTNAME</th><th>CUSTSTREETADDRESS</th><th>CUSTCITY</th><th>CUSTSTATE</th><th>CUSTZIPCODE</th><th>CUSTAREACODE</th><th>CUSTPHONENUMBER</th></tr><tr><td>1027</td><td>Allan                                             </td><td>Davis                                             </td><td>877 145th Ave SE</td><td>Portland</td><td>OR                            </td><td>97208</td><td>503</td><td>555-2316</td></tr></table>
